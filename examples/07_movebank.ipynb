# %% [markdown]
# ## Analyzing data from Movebank

# %%
import movekit as mkit

# %% [markdown]
# #### Read data input

# %%
data = mkit.read_movebank('datasets/Mangabey_monkeys_in_Uganda.csv')
data.head()
# Out:
#                  time animal_id             x             y    event-id  \
# 0 1972-05-01 05:15:00        BT  206205.00004  61229.999999  1215038324
# 1 1972-05-01 05:15:00        KT  206220.00004  61219.999999  1215038318
# 2 1972-05-01 05:15:00        LN  206210.00004  61234.999999  1215038323
# 3 1972-05-01 05:15:00   M Group  206209.00004  61220.499999  1099185632
# 4 1972-05-01 05:45:00        HK  206235.00004  61574.999999  1215038325
#
#    visible  location-long  location-lat behavioural-classification  comments  \
# 0     True      30.360556      0.553375                          ?       NaN
# 1     True      30.360691      0.553285                          ?       NaN
# 2     True      30.360601      0.553420                          ?       NaN
# 3     True      30.360592      0.553289                        NaN       9.0
# 4     True      30.360824      0.556493              FEED:DS:FRUIT       NaN
#
#   study-specific-measurement   sensor-type individual-taxon-canonical-name  \
# 0                   SUBADULT  natural-mark             Lophocebus albigena
# 1                      ADULT  natural-mark             Lophocebus albigena
# 2                      ADULT  natural-mark             Lophocebus albigena
# 3                        NaN  natural-mark             Lophocebus albigena
# 4                      ADULT  natural-mark             Lophocebus albigena
#
#   tag-local-identifier                                         study-name
# 0                   BT  Mangabey monkeys in Uganda (data from Waser 1975)
# 1                   KT  Mangabey monkeys in Uganda (data from Waser 1975)
# 2                   LN  Mangabey monkeys in Uganda (data from Waser 1975)
# 3              M Group  Mangabey monkeys in Uganda (data from Waser 1975)
# 4                   HK  Mangabey monkeys in Uganda (data from Waser 1975)

# %% [markdown]
# #### Basic Data Analysis

# %% [markdown]
# For further data analysis functions of `movekit` please refer to the other example notebooks or the documentation.
# It is important to preprocess the data from Movebank, as the data often contains duplicates which can lead to problems in further analysis steps.

# %%
data = mkit.preprocess(data, interpolation = True, date_format = True)  # important to indicate the date format of time by setting date_format=True when applying interpolation
data.head()
# Out:
# Total number of missing values =  14437
# comments                           9637
# behavioural-classification         2400
# study-specific-measurement         2400
# time                                  0
# animal_id                             0
# x                                     0
# y                                     0
# event-id                              0
# visible                               0
# location-long                         0
# location-lat                          0
# sensor-type                           0
# individual-taxon-canonical-name       0
# tag-local-identifier                  0
# study-name                            0
# dtype: int64
#                  time animal_id             x             y    event-id  \
# 0 1972-05-01 05:15:00        BT  206205.00004  61229.999999  1215038324
# 1 1972-05-01 05:15:00        KT  206220.00004  61219.999999  1215038318
# 2 1972-05-01 05:15:00        LN  206210.00004  61234.999999  1215038323
# 3 1972-05-01 05:15:00   M Group  206209.00004  61220.499999  1099185632
# 4 1972-05-01 05:45:00        HK  206235.00004  61574.999999  1215038325
#
#    visible  location-long  location-lat behavioural-classification  comments  \
# 0     True      30.360556      0.553375                          ?       NaN
# 1     True      30.360691      0.553285                          ?       NaN
# 2     True      30.360601      0.553420                          ?       NaN
# 3     True      30.360592      0.553289                        NaN       9.0
# 4     True      30.360824      0.556493              FEED:DS:FRUIT      10.0
#
#   study-specific-measurement   sensor-type individual-taxon-canonical-name  \
# 0                   SUBADULT  natural-mark             Lophocebus albigena
# 1                      ADULT  natural-mark             Lophocebus albigena
# 2                      ADULT  natural-mark             Lophocebus albigena
# 3                        NaN  natural-mark             Lophocebus albigena
# 4                      ADULT  natural-mark             Lophocebus albigena
#
#   tag-local-identifier                                         study-name
# 0                   BT  Mangabey monkeys in Uganda (data from Waser 1975)
# 1                   KT  Mangabey monkeys in Uganda (data from Waser 1975)
# 2                   LN  Mangabey monkeys in Uganda (data from Waser 1975)
# 3              M Group  Mangabey monkeys in Uganda (data from Waser 1975)
# 4                   HK  Mangabey monkeys in Uganda (data from Waser 1975)

# %%
data = mkit.extract_features(data)
data.head()
# Out:
# Extracting all absolute features: 100%|██████████| 100.0/100 [00:03<00:00, 27.23it/s]
#                  time animal_id             x             y  distance  \
# 0 1972-05-01 05:15:00        BT  206205.00004  61229.999999       0.0
# 1 1972-05-01 05:15:00        KT  206220.00004  61219.999999       0.0
# 2 1972-05-01 05:15:00        LN  206210.00004  61234.999999       0.0
# 3 1972-05-01 05:15:00   M Group  206209.00004  61220.499999       0.0
# 4 1972-05-01 05:45:00        HK  206235.00004  61574.999999       0.0
#
#     direction  turning  average_speed  average_acceleration  stopped  ...  \
# 0  (0.0, 0.0)      0.0   9.766149e-09          1.876946e-19        1  ...
# 1  (0.0, 0.0)      0.0   1.008291e-08          1.654361e-25        1  ...
# 2  (0.0, 0.0)      0.0   9.376607e-09          3.345254e-19        1  ...
# 3  (0.0, 0.0)      0.0   1.669558e-08          2.641550e-18        1  ...
# 4  (0.0, 0.0)      0.0   0.000000e+00          0.000000e+00        1  ...
#
#    visible  location-long  location-lat  behavioural-classification comments  \
# 0     True      30.360556      0.553375                           ?      0.0
# 1     True      30.360691      0.553285                           ?      0.0
# 2     True      30.360601      0.553420                           ?      0.0
# 3     True      30.360592      0.553289                           0      9.0
# 4     True      30.360824      0.556493               FEED:DS:FRUIT     10.0
#
#    study-specific-measurement   sensor-type individual-taxon-canonical-name  \
# 0                    SUBADULT  natural-mark             Lophocebus albigena
# 1                       ADULT  natural-mark             Lophocebus albigena
# 2                       ADULT  natural-mark             Lophocebus albigena
# 3                           0  natural-mark             Lophocebus albigena
# 4                       ADULT  natural-mark             Lophocebus albigena
#
#   tag-local-identifier                                         study-name
# 0                   BT  Mangabey monkeys in Uganda (data from Waser 1975)
# 1                   KT  Mangabey monkeys in Uganda (data from Waser 1975)
# 2                   LN  Mangabey monkeys in Uganda (data from Waser 1975)
# 3              M Group  Mangabey monkeys in Uganda (data from Waser 1975)
# 4                   HK  Mangabey monkeys in Uganda (data from Waser 1975)
#
# [5 rows x 21 columns]

# %%
#calculate for each animal the distance covered between 1972-5-1 and 1972-10-1 12:00:00
mkit.distance_by_time(data, '1972-5-1','1972-10-1 12:00:00')
# Out:
#    animal_id      distance
# 0         BB  29292.196235
# 1         BC  32339.850273
# 2         BR  25428.128415
# 3         BT  56379.253280
# 4         CH      0.000000
# 5         FB      0.000000
# 6         HK  44779.676823
# 7         JA      0.000000
# 8         JE  42121.957235
# 9         KT  44881.459185
# 10        LN  36373.411270
# 11   M Group  69659.023543
# 12         O  48254.273757
# 13        PB  16140.353833
# 14        RF  55879.886570
# 15         S  17618.932566
# 16        SK  22967.788494
# 17        TK  49030.622798

# %% [markdown]
# #### Create interactive maps with the geodata

# %% [markdown]
# Using the geodata interactive maps can be created. By clicking on the marker points the animal_id and the time of each marker is displayed.

# %%
# as the creation of the map is very time-confusing it is recommended to select a subsample of animals for which the map is created.
mkit.plot_geodata(data, animal_list=["BT", "KT"])
# Out:
# Plotting geo data for specified animals: 100%|██████████| 2/2 [00:00<00:00,  3.85it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e23c68118faca3dca91ea720c99ef7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e23c68118faca3dca91ea720c99ef7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7e23c68118faca3dca91ea720c99ef7d = L.map(
#                 &quot;map_7e23c68118faca3dca91ea720c99ef7d&quot;,
#                 {
#                     center: [0.553375217425551, 30.360556360350643],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb170d5fff1d42f65afe44b21f8dd6e6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e23c68118faca3dca91ea720c99ef7d);
#
#
#             var marker_1cb8e31544118acfc007e74b0cb011e2 = L.marker(
#                 [0.553375217425551, 30.360556360350643],
#                 {}
#             ).addTo(map_7e23c68118faca3dca91ea720c99ef7d);
#
#
#             var icon_2d326cf718cdcc1887a2fc749f0a3abf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1cb8e31544118acfc007e74b0cb011e2.setIcon(icon_2d326cf718cdcc1887a2fc749f0a3abf);
#
#
#         var popup_b1048f02cacebcaf46a8ccdcd0854b2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_af295b07d9e4612020ab983b35e49a93 = $(`&lt;div id=&quot;html_af295b07d9e4612020ab983b35e49a93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: BT Time: 1972-05-01 05:15:00&lt;/div&gt;`)[0];
#             popup_b1048f02cacebcaf46a8ccdcd0854b2d.setContent(html_af295b07d9e4612020ab983b35e49a93);
#
#
#         marker_1cb8e31544118acfc007e74b0cb011e2.bindPopup(popup_b1048f02cacebcaf46a8ccdcd0854b2d)
#         ;
#
#
#
#
#             marker_1cb8e31544118acfc007e74b0cb011e2.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: BT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f03cad39f95bb2c961e97c22063b0ab7 = L.marker(
#                 [0.5574424806484349, 30.361272760927555],
#                 {}
#             ).addTo(map_7e23c68118faca3dca91ea720c99ef7d);
#
#
#             var icon_92156fb41d5ec8e9636fab9ddc32b09a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f03cad39f95bb2c961e97c22063b0ab7.setIcon(icon_92156fb41d5ec8e9636fab9ddc32b09a);
#
#
#         var popup_59fbdd895136fec4b4cb5aab193a9810 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7dd57e5efda8c84346427387a3e5a465 = $(`&lt;div id=&quot;html_7dd57e5efda8c84346427387a3e5a465&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: BT Time: 1972-05-01 11:45:00&lt;/div&gt;`)[0];
#             popup_59fbdd895136fec4b4cb5aab193a9810.setContent(html_7dd57e5efda8c84346427387a3e5a465);
#
#
#         marker_f03cad39f95bb2c961e97c22063b0ab7.bindPopup(popup_59fbdd895136fec4b4cb5aab193a9810)
#         ;
#
#
#
#
#             marker_f03cad39f95bb2c961e97c22063b0ab7.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: BT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f434442d17e4ce734d3ece8d795573a4 = L.marker(
#                 [0.557352225720408, 30.361542128499718],
#                 {}
#             ).addTo(map_7e23c68118faca3dca91ea720c99ef7d);
#
#
#             var icon_3296549376c927180202654d5c8f9e64 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f434442d17e4ce734d3ece8d795573a4.setIcon(icon_3296549376c927180202654d5c8f9e64);
#
#
#         var popup_15aa41234298b9649ec8b99d88e46ac6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a8fada855b025e5dbefd3e9d408c3e2f = $(`&lt;div id=&quot;html_a8fada855b025e5dbefd3e9d408c3e2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: BT Time: 1972-05-01 12:15:00&lt;/div&gt;`)[0];
#             popup_15aa41234298b9649ec8b99d88e46ac6.setContent(html_a8fada855b025e5dbefd3e9d408c3e2f);
#
#
#         marker_f434442d17e4ce734d3ece8d795573a4.bindPopup(popup_15aa41234298b9649ec8b99d88e46ac6)
#         ;

# %% [markdown]
# Additionally the movement of individual animals can be retraced by including movement lines in between the different markers.

# %%
# each movement line has a tooltip to follow the sequence of movement (here animal "JA" for example starts in south west)
movement_map = mkit.plot_geodata(data, animal_list=["JA"], movement_lines=True)
movement_map
# Out:
# Plotting geo data for specified animals: 100%|██████████| 1/1 [00:00<00:00,  7.69it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01a84516e04abb8289a04cbde9f83d02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01a84516e04abb8289a04cbde9f83d02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_01a84516e04abb8289a04cbde9f83d02 = L.map(
#                 &quot;map_01a84516e04abb8289a04cbde9f83d02&quot;,
#                 {
#                     center: [0.549218241366192, 30.360556360350643],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cfbe96f94e79be8c3eb3051a6a61a8f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01a84516e04abb8289a04cbde9f83d02);
#
#
#             var marker_1c19a1575fadfae32884f182f9f34dd9 = L.marker(
#                 [0.549218241366192, 30.36132128488707],
#                 {}
#             ).addTo(map_01a84516e04abb8289a04cbde9f83d02);
#
#
#             var icon_45e28876965119544095ba3c4bb6cae1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1c19a1575fadfae32884f182f9f34dd9.setIcon(icon_45e28876965119544095ba3c4bb6cae1);
#
#
#         var popup_db9c70098a68c7cb82dfe83d61cd5028 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f2d9dc0b2f05796a534c743a22536664 = $(`&lt;div id=&quot;html_f2d9dc0b2f05796a534c743a22536664&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: JA Time: 1973-01-29 05:45:00&lt;/div&gt;`)[0];
#             popup_db9c70098a68c7cb82dfe83d61cd5028.setContent(html_f2d9dc0b2f05796a534c743a22536664);
#
#
#         marker_1c19a1575fadfae32884f182f9f34dd9.bindPopup(popup_db9c70098a68c7cb82dfe83d61cd5028)
#         ;
#
#
#
#
#             marker_1c19a1575fadfae32884f182f9f34dd9.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: JA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_364c15570f9b9f295a2f9b6ae3330c18 = L.marker(
#                 [0.5490828163421521, 30.361635559160327],
#                 {}
#             ).addTo(map_01a84516e04abb8289a04cbde9f83d02);
#
#
#             var icon_2fb0da7dcda41f136c7acee938d724d9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_364c15570f9b9f295a2f9b6ae3330c18.setIcon(icon_2fb0da7dcda41f136c7acee938d724d9);
#
#
#         var popup_06df5a89e1184eb8fb3e727a677c7c63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d69b34885a2cd388f9841802890f673d = $(`&lt;div id=&quot;html_d69b34885a2cd388f9841802890f673d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: JA Time: 1973-01-29 06:45:00&lt;/div&gt;`)[0];
#             popup_06df5a89e1184eb8fb3e727a677c7c63.setContent(html_d69b34885a2cd388f9841802890f673d);
#
#
#         marker_364c15570f9b9f295a2f9b6ae3330c18.bindPopup(popup_06df5a89e1184eb8fb3e727a677c7c63)
#         ;
#
#
#
#
#             marker_364c15570f9b9f295a2f9b6ae3330c18.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: JA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_33c0a1dd5358fbae8b5c85d007fc816a = L.polyline(
#                 [[0.549218241366192, 30.36132128488707], [0.5490828163421521, 30.361635559160327]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_01a84516e04abb8289a04cbde9f83d02);
#
#
#         var popup_9d691bfa9836f4ab59f0fd7d01c64e85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b6c47c6c44c6d2d4e5474d91c94fb0b6 = $(`&lt;div id=&quot;html_b6c47c6c44c6d2d4e5474d91c94fb0b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time Range of movement: From 1973-01-29 05:45:00 to 1973-01-29 06:45:00&lt;/div&gt;`)[0];
#             popup_9d691bfa9836f4ab59f0fd7d01c64e85.setContent(html_b6c47c6c44c6d2d4e5474d91c94fb0b6);

# %% [markdown]
# The created maps can also be saved locally.

# %%
#mkit.save_geodata_map(movement_map, "mymap.html")
