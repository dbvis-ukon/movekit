# %% [markdown]
# ## Analyzing data from Movebank

# %%
import movekit as mkit

# %% [markdown]
# #### Read data input

# %%
data = mkit.read_movebank('datasets/Mangabey_monkeys_in_Uganda.csv')
data.head()
# Out:
#                     time animal_id             x             y    event-id  \
# 1337 1972-05-01 05:15:00        BT  206205.00004  61229.999999  1215038324
# 0    1972-05-01 05:15:00        KT  206220.00004  61219.999999  1215038318
# 710  1972-05-01 05:15:00        LN  206210.00004  61234.999999  1215038323
# 9637 1972-05-01 05:15:00   M Group  206209.00004  61220.499999  1099185632
# 2148 1972-05-01 05:45:00        HK  206235.00004  61574.999999  1215038325
#
#       visible  location-long  location-lat behavioural-classification  \
# 1337     True      30.360556      0.553375                          ?
# 0        True      30.360691      0.553285                          ?
# 710      True      30.360601      0.553420                          ?
# 9637     True      30.360592      0.553289                        NaN
# 2148     True      30.360824      0.556493              FEED:DS:FRUIT
#
#       comments study-specific-measurement   sensor-type  \
# 1337       NaN                   SUBADULT  natural-mark
# 0          NaN                      ADULT  natural-mark
# 710        NaN                      ADULT  natural-mark
# 9637       9.0                        NaN  natural-mark
# 2148       NaN                      ADULT  natural-mark
#
#      individual-taxon-canonical-name tag-local-identifier  \
# 1337             Lophocebus albigena                   BT
# 0                Lophocebus albigena                   KT
# 710              Lophocebus albigena                   LN
# 9637             Lophocebus albigena              M Group
# 2148             Lophocebus albigena                   HK
#
#                                              study-name
# 1337  Mangabey monkeys in Uganda (data from Waser 1975)
# 0     Mangabey monkeys in Uganda (data from Waser 1975)
# 710   Mangabey monkeys in Uganda (data from Waser 1975)
# 9637  Mangabey monkeys in Uganda (data from Waser 1975)
# 2148  Mangabey monkeys in Uganda (data from Waser 1975)

# %% [markdown]
# #### Basic Data Analysis

# %% [markdown]
# For further data analysis functions of `movekit` please refer to the other example notebooks or the documentation.
# It is important to preprocess the data from Movebank, as the data often contains duplicates which can lead to problems in further analysis steps.

# %%
data = mkit.preprocess(data, interpolation = True, date_format = True)  # important to indicate the date format of time by setting date_format=True when applying interpolation
data.head()
# Out:
# Total number of missing values =  14437
# comments                           9637
# behavioural-classification         2400
# study-specific-measurement         2400
# time                                  0
# animal_id                             0
# x                                     0
# y                                     0
# event-id                              0
# visible                               0
# location-long                         0
# location-lat                          0
# sensor-type                           0
# individual-taxon-canonical-name       0
# tag-local-identifier                  0
# study-name                            0
# dtype: int64
#                     time animal_id             x             y    event-id  \
# 1337 1972-05-01 05:15:00        BT  206205.00004  61229.999999  1215038324
# 0    1972-05-01 05:15:00        KT  206220.00004  61219.999999  1215038318
# 710  1972-05-01 05:15:00        LN  206210.00004  61234.999999  1215038323
# 9637 1972-05-01 05:15:00   M Group  206209.00004  61220.499999  1099185632
# 2148 1972-05-01 05:45:00        HK  206235.00004  61574.999999  1215038325
#
#       visible  location-long  location-lat behavioural-classification  \
# 1337     True      30.360556      0.553375                          ?
# 0        True      30.360691      0.553285                          ?
# 710      True      30.360601      0.553420                          ?
# 9637     True      30.360592      0.553289                        NaN
# 2148     True      30.360824      0.556493              FEED:DS:FRUIT
#
#       comments study-specific-measurement   sensor-type  \
# 1337       NaN                   SUBADULT  natural-mark
# 0          NaN                      ADULT  natural-mark
# 710        NaN                      ADULT  natural-mark
# 9637       9.0                        NaN  natural-mark
# 2148      10.0                      ADULT  natural-mark
#
#      individual-taxon-canonical-name tag-local-identifier  \
# 1337             Lophocebus albigena                   BT
# 0                Lophocebus albigena                   KT
# 710              Lophocebus albigena                   LN
# 9637             Lophocebus albigena              M Group
# 2148             Lophocebus albigena                   HK
#
#                                              study-name
# 1337  Mangabey monkeys in Uganda (data from Waser 1975)
# 0     Mangabey monkeys in Uganda (data from Waser 1975)
# 710   Mangabey monkeys in Uganda (data from Waser 1975)
# 9637  Mangabey monkeys in Uganda (data from Waser 1975)
# 2148  Mangabey monkeys in Uganda (data from Waser 1975)

# %%
data = mkit.extract_features(data)
data.head()
# Out:
# Extracting all absolute features: 100%|██████████| 100.0/100 [00:03<00:00, 32.24it/s]
#                  time animal_id             x             y  distance  \
# 0 1972-05-01 05:15:00        BT  206205.00004  61229.999999       0.0
# 1 1972-05-01 05:15:00        KT  206220.00004  61219.999999       0.0
# 2 1972-05-01 05:15:00        LN  206210.00004  61234.999999       0.0
# 3 1972-05-01 05:15:00   M Group  206209.00004  61220.499999       0.0
# 4 1972-05-01 05:45:00        HK  206235.00004  61574.999999       0.0
#
#     direction  turning  average_speed  average_acceleration  stopped  ...  \
# 0  (0.0, 0.0)      0.0     144.909354             -6.750061        0  ...
# 1  (0.0, 0.0)      0.0      89.757240              8.491764        0  ...
# 2  (0.0, 0.0)      0.0     280.498911              3.702460        0  ...
# 3  (0.0, 0.0)      0.0      41.606821             -0.149840        0  ...
# 4  (0.0, 0.0)      0.0     243.150166             -7.612515        0  ...
#
#    visible  location-long  location-lat  behavioural-classification comments  \
# 0     True      30.360556      0.553375                           ?      0.0
# 1     True      30.360691      0.553285                           ?      0.0
# 2     True      30.360601      0.553420                           ?      0.0
# 3     True      30.360592      0.553289                           0      9.0
# 4     True      30.360824      0.556493               FEED:DS:FRUIT     10.0
#
#    study-specific-measurement   sensor-type individual-taxon-canonical-name  \
# 0                    SUBADULT  natural-mark             Lophocebus albigena
# 1                       ADULT  natural-mark             Lophocebus albigena
# 2                       ADULT  natural-mark             Lophocebus albigena
# 3                           0  natural-mark             Lophocebus albigena
# 4                       ADULT  natural-mark             Lophocebus albigena
#
#   tag-local-identifier                                         study-name
# 0                   BT  Mangabey monkeys in Uganda (data from Waser 1975)
# 1                   KT  Mangabey monkeys in Uganda (data from Waser 1975)
# 2                   LN  Mangabey monkeys in Uganda (data from Waser 1975)
# 3              M Group  Mangabey monkeys in Uganda (data from Waser 1975)
# 4                   HK  Mangabey monkeys in Uganda (data from Waser 1975)
#
# [5 rows x 21 columns]

# %%
#calculate for each animal the distance covered between 1972-5-1 and 1972-10-1 12:00:00
mkit.distance_by_time(data, '1972-5-1','1972-10-1 12:00:00')
# Out:
#    animal_id      distance
# 0         BB  29292.196235
# 1         BC  32339.850273
# 2         BR  25428.128415
# 3         BT  56379.253280
# 4         CH      0.000000
# 5         FB      0.000000
# 6         HK  44779.676823
# 7         JA      0.000000
# 8         JE  42121.957235
# 9         KT  44881.459185
# 10        LN  36373.411270
# 11   M Group  69659.023543
# 12         O  48254.273757
# 13        PB  16140.353833
# 14        RF  55879.886570
# 15         S  17618.932566
# 16        SK  22967.788494
# 17        TK  49030.622798

# %% [markdown]
# #### Create interactive maps with the geodata

# %% [markdown]
# Using the geodata interactive maps can be created. By clicking on the marker points the animal_id and the time of each marker is displayed.

# %%
# as the creation of the map is very time-confusing it is recommended to select a subsample of animals for which the map is created.
mkit.plot_geodata(data, animal_list=["BT", "KT"])
# Out:
# Plotting geo data for specified animals: 100%|██████████| 2/2 [00:00<00:00,  4.34it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9638fd330f8585f83ea2433b3760ba8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9638fd330f8585f83ea2433b3760ba8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9638fd330f8585f83ea2433b3760ba8b = L.map(
#                 &quot;map_9638fd330f8585f83ea2433b3760ba8b&quot;,
#                 {
#                     center: [0.553375217425551, 30.36069106380197],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a0f2796a54598691ac3ec8a131eb2d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9638fd330f8585f83ea2433b3760ba8b);
#
#
#             var marker_c2589af37163f7de8f52397b7230d144 = L.marker(
#                 [0.553375217425551, 30.360556360350643],
#                 {}
#             ).addTo(map_9638fd330f8585f83ea2433b3760ba8b);
#
#
#             var icon_ec197643b8126c64c613145dacf33b03 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2589af37163f7de8f52397b7230d144.setIcon(icon_ec197643b8126c64c613145dacf33b03);
#
#
#         var popup_3a4230d3280a5342a0a9e23b1f98b29c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_26fc78c555dbc15151fd83e2730a64a3 = $(`&lt;div id=&quot;html_26fc78c555dbc15151fd83e2730a64a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: BT Time: 1972-05-01 05:15:00&lt;/div&gt;`)[0];
#             popup_3a4230d3280a5342a0a9e23b1f98b29c.setContent(html_26fc78c555dbc15151fd83e2730a64a3);
#
#
#         marker_c2589af37163f7de8f52397b7230d144.bindPopup(popup_3a4230d3280a5342a0a9e23b1f98b29c)
#         ;
#
#
#
#
#             marker_c2589af37163f7de8f52397b7230d144.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: BT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dcd0da8e36f3ad1e827c5053ed5ad859 = L.marker(
#                 [0.5574424806484349, 30.361272760927555],
#                 {}
#             ).addTo(map_9638fd330f8585f83ea2433b3760ba8b);
#
#
#             var icon_59b83f34a79c3dbb5ecea0391fbf39b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dcd0da8e36f3ad1e827c5053ed5ad859.setIcon(icon_59b83f34a79c3dbb5ecea0391fbf39b8);
#
#
#         var popup_9b41acbe0008b2b851fd3fd829eee8b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3b36df1500c62bf86ae0b07e583e34e7 = $(`&lt;div id=&quot;html_3b36df1500c62bf86ae0b07e583e34e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: BT Time: 1972-05-01 11:45:00&lt;/div&gt;`)[0];
#             popup_9b41acbe0008b2b851fd3fd829eee8b0.setContent(html_3b36df1500c62bf86ae0b07e583e34e7);
#
#
#         marker_dcd0da8e36f3ad1e827c5053ed5ad859.bindPopup(popup_9b41acbe0008b2b851fd3fd829eee8b0)
#         ;
#
#
#
#
#             marker_dcd0da8e36f3ad1e827c5053ed5ad859.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: BT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_16686daeada4ea9fac880552212acf4f = L.marker(
#                 [0.557352225720408, 30.361542128499718],
#                 {}
#             ).addTo(map_9638fd330f8585f83ea2433b3760ba8b);
#
#
#             var icon_522ae6a3db0b6f153e0ad94048e671cf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16686daeada4ea9fac880552212acf4f.setIcon(icon_522ae6a3db0b6f153e0ad94048e671cf);
#
#
#         var popup_0f453fbf1547a84a9077310e8b4a6f6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_77b80fd867341356075e5da50fc82094 = $(`&lt;div id=&quot;html_77b80fd867341356075e5da50fc82094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: BT Time: 1972-05-01 12:15:00&lt;/div&gt;`)[0];
#             popup_0f453fbf1547a84a9077310e8b4a6f6f.setContent(html_77b80fd867341356075e5da50fc82094);
#
#
#         marker_16686daeada4ea9fac880552212acf4f.bindPopup(popup_0f453fbf1547a84a9077310e8b4a6f6f)
#         ;

# %% [markdown]
# Additionally the movement of individual animals can be retraced by including movement lines in between the different markers.

# %%
# each movement line has a tooltip to follow the sequence of movement (here animal "JA" for example starts in south west)
movement_map = mkit.plot_geodata(data, animal_list=["JA"], movement_lines=True)
movement_map
# Out:
# Plotting geo data for specified animals: 100%|██████████| 1/1 [00:00<00:00,  8.70it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76bd622280a223c5f3de2051fec5696f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76bd622280a223c5f3de2051fec5696f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_76bd622280a223c5f3de2051fec5696f = L.map(
#                 &quot;map_76bd622280a223c5f3de2051fec5696f&quot;,
#                 {
#                     center: [0.549218241366192, 30.36069106380197],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e155781505cf7cecfd1c7768f8fbbfe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_76bd622280a223c5f3de2051fec5696f);
#
#
#             var marker_f50c471b10807007d20dbfb4e518a8e6 = L.marker(
#                 [0.549218241366192, 30.36132128488707],
#                 {}
#             ).addTo(map_76bd622280a223c5f3de2051fec5696f);
#
#
#             var icon_0be174305c26e1b68cd75a53d3fe4f18 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f50c471b10807007d20dbfb4e518a8e6.setIcon(icon_0be174305c26e1b68cd75a53d3fe4f18);
#
#
#         var popup_510b09eaf186eadc4c13d928841b5176 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e1ead47d1c9bffa96b81b5d46c29a10 = $(`&lt;div id=&quot;html_7e1ead47d1c9bffa96b81b5d46c29a10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: JA Time: 1973-01-29 05:45:00&lt;/div&gt;`)[0];
#             popup_510b09eaf186eadc4c13d928841b5176.setContent(html_7e1ead47d1c9bffa96b81b5d46c29a10);
#
#
#         marker_f50c471b10807007d20dbfb4e518a8e6.bindPopup(popup_510b09eaf186eadc4c13d928841b5176)
#         ;
#
#
#
#
#             marker_f50c471b10807007d20dbfb4e518a8e6.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: JA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9735c958edb9c83e8c7674d0354654c0 = L.marker(
#                 [0.5490828163421521, 30.361635559160327],
#                 {}
#             ).addTo(map_76bd622280a223c5f3de2051fec5696f);
#
#
#             var icon_41fab13c0857e8ddcb75cb5ddee20485 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9735c958edb9c83e8c7674d0354654c0.setIcon(icon_41fab13c0857e8ddcb75cb5ddee20485);
#
#
#         var popup_515dca88d418cd7c5e27193931fd401b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ead00aeb8d2e2067a919b7a0b027454c = $(`&lt;div id=&quot;html_ead00aeb8d2e2067a919b7a0b027454c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: JA Time: 1973-01-29 06:45:00&lt;/div&gt;`)[0];
#             popup_515dca88d418cd7c5e27193931fd401b.setContent(html_ead00aeb8d2e2067a919b7a0b027454c);
#
#
#         marker_9735c958edb9c83e8c7674d0354654c0.bindPopup(popup_515dca88d418cd7c5e27193931fd401b)
#         ;
#
#
#
#
#             marker_9735c958edb9c83e8c7674d0354654c0.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: JA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_ae53c165c0fd86e55dafd44fda487f7b = L.polyline(
#                 [[0.549218241366192, 30.36132128488707], [0.5490828163421521, 30.361635559160327]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_76bd622280a223c5f3de2051fec5696f);
#
#
#         var popup_0f48b0007e5541e5160aa10a09369464 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5135eee1fe337ea6071b86435bac8913 = $(`&lt;div id=&quot;html_5135eee1fe337ea6071b86435bac8913&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Time Range of movement: From 1973-01-29 05:45:00 to 1973-01-29 06:45:00&lt;/div&gt;`)[0];
#             popup_0f48b0007e5541e5160aa10a09369464.setContent(html_5135eee1fe337ea6071b86435bac8913);

# %% [markdown]
# The created maps can also be saved locally.

# %%
#mkit.save_geodata_map(movement_map, "mymap.html")
