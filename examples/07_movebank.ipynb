# %% [markdown]
# ## Analyzing data from Movebank

# %%
import movekit as mkit

# %% [markdown]
# #### Read data input

# %%
data = mkit.read_movebank('datasets/Mangabey_monkeys_in_Uganda.csv')
data.head()
# Out:
#                  time animal_id             x             y    event-id  \
# 0 1972-05-01 05:15:00        BT  206205.00004  61229.999999  1215038324
# 1 1972-05-01 05:15:00        KT  206220.00004  61219.999999  1215038318
# 2 1972-05-01 05:15:00        LN  206210.00004  61234.999999  1215038323
# 3 1972-05-01 05:15:00   M Group  206209.00004  61220.499999  1099185632
# 4 1972-05-01 05:45:00        HK  206235.00004  61574.999999  1215038325
#
#    visible  location-long  location-lat behavioural-classification  comments  \
# 0     True      30.360556      0.553375                          ?       NaN
# 1     True      30.360691      0.553285                          ?       NaN
# 2     True      30.360601      0.553420                          ?       NaN
# 3     True      30.360592      0.553289                        NaN       9.0
# 4     True      30.360824      0.556493              FEED:DS:FRUIT       NaN
#
#   study-specific-measurement   sensor-type individual-taxon-canonical-name  \
# 0                   SUBADULT  natural-mark             Lophocebus albigena
# 1                      ADULT  natural-mark             Lophocebus albigena
# 2                      ADULT  natural-mark             Lophocebus albigena
# 3                        NaN  natural-mark             Lophocebus albigena
# 4                      ADULT  natural-mark             Lophocebus albigena
#
#   tag-local-identifier                                         study-name
# 0                   BT  Mangabey monkeys in Uganda (data from Waser 1975)
# 1                   KT  Mangabey monkeys in Uganda (data from Waser 1975)
# 2                   LN  Mangabey monkeys in Uganda (data from Waser 1975)
# 3              M Group  Mangabey monkeys in Uganda (data from Waser 1975)
# 4                   HK  Mangabey monkeys in Uganda (data from Waser 1975)

# %% [markdown]
# #### Basic Data Analysis

# %% [markdown]
# For further data analysis functions of `movekit` please refer to the other example notebooks or the documentation.
# It is important to preprocess the data from Movebank, as the data often contains duplicates which can lead to problems in further analysis steps.

# %%
data = mkit.preprocess(data, interpolation = True, date_format = True)  # important to indicate the date format of time by setting date_format=True when applying interpolation
data.head()
# Out:
# Total number of missing values =  14437
# comments                           9637
# behavioural-classification         2400
# study-specific-measurement         2400
# time                                  0
# animal_id                             0
# x                                     0
# y                                     0
# event-id                              0
# visible                               0
# location-long                         0
# location-lat                          0
# sensor-type                           0
# individual-taxon-canonical-name       0
# tag-local-identifier                  0
# study-name                            0
# dtype: int64
#                  time animal_id             x             y    event-id  \
# 0 1972-05-01 05:15:00        BT  206205.00004  61229.999999  1215038324
# 1 1972-05-01 05:15:00        KT  206220.00004  61219.999999  1215038318
# 2 1972-05-01 05:15:00        LN  206210.00004  61234.999999  1215038323
# 3 1972-05-01 05:15:00   M Group  206209.00004  61220.499999  1099185632
# 4 1972-05-01 05:45:00        HK  206235.00004  61574.999999  1215038325
#
#    visible  location-long  location-lat behavioural-classification  comments  \
# 0     True      30.360556      0.553375                          ?       NaN
# 1     True      30.360691      0.553285                          ?       NaN
# 2     True      30.360601      0.553420                          ?       NaN
# 3     True      30.360592      0.553289                        NaN       9.0
# 4     True      30.360824      0.556493              FEED:DS:FRUIT      10.0
#
#   study-specific-measurement   sensor-type individual-taxon-canonical-name  \
# 0                   SUBADULT  natural-mark             Lophocebus albigena
# 1                      ADULT  natural-mark             Lophocebus albigena
# 2                      ADULT  natural-mark             Lophocebus albigena
# 3                        NaN  natural-mark             Lophocebus albigena
# 4                      ADULT  natural-mark             Lophocebus albigena
#
#   tag-local-identifier                                         study-name
# 0                   BT  Mangabey monkeys in Uganda (data from Waser 1975)
# 1                   KT  Mangabey monkeys in Uganda (data from Waser 1975)
# 2                   LN  Mangabey monkeys in Uganda (data from Waser 1975)
# 3              M Group  Mangabey monkeys in Uganda (data from Waser 1975)
# 4                   HK  Mangabey monkeys in Uganda (data from Waser 1975)

# %%
data = mkit.extract_features(data)
data.head()
# Out:
# Extracting all absolute features: 100%|██████████| 100.0/100 [00:03<00:00, 30.18it/s]
#                  time animal_id             x             y  distance  \
# 0 1972-05-01 05:15:00        BT  206205.00004  61229.999999       0.0
# 1 1972-05-01 05:15:00        KT  206220.00004  61219.999999       0.0
# 2 1972-05-01 05:15:00        LN  206210.00004  61234.999999       0.0
# 3 1972-05-01 05:15:00   M Group  206209.00004  61220.499999       0.0
# 4 1972-05-01 05:45:00        HK  206235.00004  61574.999999       0.0
#
#     direction  turning  average_speed  average_acceleration  stopped  ...  \
# 0  (0.0, 0.0)      0.0   9.766149e-09          1.876946e-19        1  ...
# 1  (0.0, 0.0)      0.0   1.008291e-08          1.654361e-25        1  ...
# 2  (0.0, 0.0)      0.0   9.376607e-09          3.345254e-19        1  ...
# 3  (0.0, 0.0)      0.0   1.669558e-08          2.641550e-18        1  ...
# 4  (0.0, 0.0)      0.0   0.000000e+00          0.000000e+00        1  ...
#
#    visible  location-long  location-lat  behavioural-classification comments  \
# 0     True      30.360556      0.553375                           ?      0.0
# 1     True      30.360691      0.553285                           ?      0.0
# 2     True      30.360601      0.553420                           ?      0.0
# 3     True      30.360592      0.553289                           0      9.0
# 4     True      30.360824      0.556493               FEED:DS:FRUIT     10.0
#
#    study-specific-measurement   sensor-type individual-taxon-canonical-name  \
# 0                    SUBADULT  natural-mark             Lophocebus albigena
# 1                       ADULT  natural-mark             Lophocebus albigena
# 2                       ADULT  natural-mark             Lophocebus albigena
# 3                           0  natural-mark             Lophocebus albigena
# 4                       ADULT  natural-mark             Lophocebus albigena
#
#   tag-local-identifier                                         study-name
# 0                   BT  Mangabey monkeys in Uganda (data from Waser 1975)
# 1                   KT  Mangabey monkeys in Uganda (data from Waser 1975)
# 2                   LN  Mangabey monkeys in Uganda (data from Waser 1975)
# 3              M Group  Mangabey monkeys in Uganda (data from Waser 1975)
# 4                   HK  Mangabey monkeys in Uganda (data from Waser 1975)
#
# [5 rows x 21 columns]

# %%
#calculate for each animal the distance covered between 1972-5-1 and 1972-10-1 12:00:00
mkit.distance_by_time(data, '1972-5-1','1972-10-1 12:00:00')
# Out:
#    animal_id      distance
# 0         BB  29292.196235
# 1         BC  32339.850273
# 2         BR  25428.128415
# 3         BT  56379.253280
# 4         CH      0.000000
# 5         FB      0.000000
# 6         HK  44779.676823
# 7         JA      0.000000
# 8         JE  42121.957235
# 9         KT  44881.459185
# 10        LN  36373.411270
# 11   M Group  69659.023543
# 12         O  48254.273757
# 13        PB  16140.353833
# 14        RF  55879.886570
# 15         S  17618.932566
# 16        SK  22967.788494
# 17        TK  49030.622798

# %% [markdown]
# #### Create interactive maps with the geodata

# %% [markdown]
# Using the geodata interactive maps can be created. By clicking on the marker points the animal_id and the time of each marker is displayed.

# %%
# as the creation of the map is very time-confusing it is recommended to select a subsample of animals for which the map is created.
mkit.plot_geodata(data, animal_list=["BT", "KT"])
# Out:
# /Users/timkleinlein/DbvisHiwi/movekit/g/lib/python3.9/site-packages/movekit-0.0.0-py3.9.egg/movekit/plot.py:184: UserWarning: As plotting the geodata on an interactive map is  very time-consuming, it is recommended to reduce the size of the data as much as possible.
#   warnings.warn("As plotting the geodata on an interactive map is  very time-consuming, it is recommended to reduce the size of the data as much as possible.")
# Plotting geo data for specified animals: 100%|██████████| 2/2 [00:00<00:00,  5.45it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52b97e6cfa5dc24b94603454792fb4bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52b97e6cfa5dc24b94603454792fb4bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52b97e6cfa5dc24b94603454792fb4bc = L.map(
#                 &quot;map_52b97e6cfa5dc24b94603454792fb4bc&quot;,
#                 {
#                     center: [0.553375217425551, 30.360556360350643],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c24a40bc14e9f04b3111e6fe5779d7ef = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52b97e6cfa5dc24b94603454792fb4bc);
#
#
#             var marker_c32f1a88a15e5d6a59d7036d15867968 = L.marker(
#                 [0.553375217425551, 30.360556360350643],
#                 {}
#             ).addTo(map_52b97e6cfa5dc24b94603454792fb4bc);
#
#
#             var icon_515e8bb120a63772a76081e13c4d6704 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c32f1a88a15e5d6a59d7036d15867968.setIcon(icon_515e8bb120a63772a76081e13c4d6704);
#
#
#         var popup_9d57e34c20ab0c0d50f496a133a131b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ea624c4a43754e48b93096519029ef0 = $(`&lt;div id=&quot;html_5ea624c4a43754e48b93096519029ef0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: BT Time: 1972-05-01 05:15:00&lt;/div&gt;`)[0];
#                 popup_9d57e34c20ab0c0d50f496a133a131b9.setContent(html_5ea624c4a43754e48b93096519029ef0);
#
#
#
#         marker_c32f1a88a15e5d6a59d7036d15867968.bindPopup(popup_9d57e34c20ab0c0d50f496a133a131b9)
#         ;
#
#
#
#
#             marker_c32f1a88a15e5d6a59d7036d15867968.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: BT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b47703ec670c70acbfa6ca16ea1203c5 = L.marker(
#                 [0.5574424806484349, 30.361272760927555],
#                 {}
#             ).addTo(map_52b97e6cfa5dc24b94603454792fb4bc);
#
#
#             var icon_9e6d991077098ce6ae69bf62adced3b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b47703ec670c70acbfa6ca16ea1203c5.setIcon(icon_9e6d991077098ce6ae69bf62adced3b2);
#
#
#         var popup_6f04aa4d00f6aa302ec4a41ec7f3ef12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_887ccbd851cad0dc45ec3fd2cf6cd53b = $(`&lt;div id=&quot;html_887ccbd851cad0dc45ec3fd2cf6cd53b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: BT Time: 1972-05-01 11:45:00&lt;/div&gt;`)[0];
#                 popup_6f04aa4d00f6aa302ec4a41ec7f3ef12.setContent(html_887ccbd851cad0dc45ec3fd2cf6cd53b);
#
#
#
#         marker_b47703ec670c70acbfa6ca16ea1203c5.bindPopup(popup_6f04aa4d00f6aa302ec4a41ec7f3ef12)
#         ;
#
#
#
#
#             marker_b47703ec670c70acbfa6ca16ea1203c5.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: BT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_24a1b886d69d1c5b264e09af1e5a4952 = L.marker(
#                 [0.557352225720408, 30.361542128499718],
#                 {}
#             ).addTo(map_52b97e6cfa5dc24b94603454792fb4bc);
#
#
#             var icon_886975879f1baa72c877d1f8966f27ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_24a1b886d69d1c5b264e09af1e5a4952.setIcon(icon_886975879f1baa72c877d1f8966f27ee);
#
#
#         var popup_8f166b7b80960e87e4a524bb74649bdc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac3f8ff3f53fe535cfd1c360201ceea9 = $(`&lt;div id=&quot;html_ac3f8ff3f53fe535cfd1c360201ceea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: BT Time: 1972-05-01 12:15:00&lt;/div&gt;`)[0];
#                 p

# %% [markdown]
# Additionally the movement of individual animals can be retraced by including movement lines in between the different markers.

# %%
# each movement line has a tooltip to follow the sequence of movement (here animal "JA" for example starts in south west)
movement_map = mkit.plot_geodata(data, animal_list=["JA"], movement_lines=True)
movement_map
# Out:
# /Users/timkleinlein/DbvisHiwi/movekit/g/lib/python3.9/site-packages/movekit-0.0.0-py3.9.egg/movekit/plot.py:184: UserWarning: As plotting the geodata on an interactive map is  very time-consuming, it is recommended to reduce the size of the data as much as possible.
#   warnings.warn("As plotting the geodata on an interactive map is  very time-consuming, it is recommended to reduce the size of the data as much as possible.")
# Plotting geo data for specified animals: 100%|██████████| 1/1 [00:00<00:00,  4.46it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30be98a13497fdbf0bb158670c40e5d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30be98a13497fdbf0bb158670c40e5d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30be98a13497fdbf0bb158670c40e5d3 = L.map(
#                 &quot;map_30be98a13497fdbf0bb158670c40e5d3&quot;,
#                 {
#                     center: [0.549218241366192, 30.360556360350643],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ff6b7dcdb3273a6495b05e962628f01 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_30be98a13497fdbf0bb158670c40e5d3);
#
#
#             var marker_18af935a39dac1a8ab9ea0efd084907a = L.marker(
#                 [0.549218241366192, 30.36132128488707],
#                 {}
#             ).addTo(map_30be98a13497fdbf0bb158670c40e5d3);
#
#
#             var icon_13abcd8cfea599cfb9c1112de073efae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_18af935a39dac1a8ab9ea0efd084907a.setIcon(icon_13abcd8cfea599cfb9c1112de073efae);
#
#
#         var popup_1e2046c0e5674d9f253a6b8a1504097d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02956c8c3664a66e5bc4ac8b238b743f = $(`&lt;div id=&quot;html_02956c8c3664a66e5bc4ac8b238b743f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: JA Time: 1973-01-29 05:45:00&lt;/div&gt;`)[0];
#                 popup_1e2046c0e5674d9f253a6b8a1504097d.setContent(html_02956c8c3664a66e5bc4ac8b238b743f);
#
#
#
#         marker_18af935a39dac1a8ab9ea0efd084907a.bindPopup(popup_1e2046c0e5674d9f253a6b8a1504097d)
#         ;
#
#
#
#
#             marker_18af935a39dac1a8ab9ea0efd084907a.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: JA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5b292cad93827952b8ad2bfba5ab2707 = L.marker(
#                 [0.5490828163421521, 30.361635559160327],
#                 {}
#             ).addTo(map_30be98a13497fdbf0bb158670c40e5d3);
#
#
#             var icon_cbba361374152a4d74db076cac242a2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5b292cad93827952b8ad2bfba5ab2707.setIcon(icon_cbba361374152a4d74db076cac242a2e);
#
#
#         var popup_d5edf6c6699b71ff63fbcab78681be19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51c385dacf8fdc4964d46a5e878f477c = $(`&lt;div id=&quot;html_51c385dacf8fdc4964d46a5e878f477c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Animal ID: JA Time: 1973-01-29 06:45:00&lt;/div&gt;`)[0];
#                 popup_d5edf6c6699b71ff63fbcab78681be19.setContent(html_51c385dacf8fdc4964d46a5e878f477c);
#
#
#
#         marker_5b292cad93827952b8ad2bfba5ab2707.bindPopup(popup_d5edf6c6699b71ff63fbcab78681be19)
#         ;
#
#
#
#
#             marker_5b292cad93827952b8ad2bfba5ab2707.bindTooltip(
#                 `&lt;div&gt;
#                      Animal ID: JA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_fc02b5b153f1e6edf6c08648bf46663d = L.polyline(
#                 [[0.549218241366192, 30.36132128488707], [0.5490828163421521, 30.361635559160327]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_30be98a13497fdbf0bb158670c40e5d3);
#
#
#         var popup_0d09976d2c90b9886895fa0755d01aa1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b0c4c6c4e34fc057b24718aac8db23d = $(`&lt;div id=&quot;html_3b0c4c6c4e34fc057b24718aac8db23d&quot; style=&quot;width: 100.0%; height

# %% [markdown]
# The created maps can also be saved locally.

# %%
#mkit.save_geodata_map(movement_map, "mymap.html")
